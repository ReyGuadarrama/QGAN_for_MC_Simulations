# %% [markdown]
# ### **Libraries**

# %%
# Library imports
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pennylane as qml
import h5py

# Pytorch imports
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from python_package.metrics import FID
from IPython.display import clear_output
from itertools import product
from python_package.qg_test import ModelTest



# Set the random seed for reproducibility
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# %% [markdown]
# # **Model specs**

# %%
test = ModelTest(
    test_id = '08',
    num_qubits = 9,
    num_aux_qubits = 4,
    circuit_depth = 12,
    num_generators = 16,
    rotations = ['Y'],
    generator_lr = 0.0001,
    discriminator_lr = 0.0001,
    batch_size = 1,
    num_samples = 256,
    num_epochs = 50,
    y = 0.28,
    channel = 'ECAL-HCAL',
    optimizer= 'SGD',
    resolution= '16x16',
    cut_threshold= 0.001,
    shift=0
)

test.display_specs()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 test = ModelTest(
#       2     test_id = '08',
#       3     num_qubits = 9,
#       4     num_aux_qubits = 4,
#       5     circuit_depth = 12,
#       6     num_generators = 16,
#       7     rotations = ['Y'],
#       8     generator_lr = 0.0001,
#       9     discriminator_lr = 0.0001,
#      10     batch_size = 1,
#      11     num_samples = 256,
#      12     num_epochs = 50,
#      13     y = 0.28,
#      14     channel = 'ECAL-HCAL',
#      15     optimizer= 'SGD',
#      16     resolution= '16x16',
#      17     cut_threshold= 0.001,
#      18     shift=0
#      19 )
#      21 test.display_specs()
#
# File ~/GSoC/src/python_package/qg_test.py:39, in ModelTest.__init__(self, test_id, num_qubits, num_aux_qubits, circuit_depth, rotations, num_generators, generator_lr, discriminator_lr, batch_size, num_samples, num_epochs, y, channel, optimizer, resolution, cut_threshold, shift)
#      35 self.path = os.path.join(self.current_dir, '..', '..', 'tests', channel+'_tests', 'log')
#      38 # Check for existing test ID
# ---> 39 self._check_existing_test_id()
#      40 self._check_identical_test()
#      42 # Create Specs JSON
#
# File ~/GSoC/src/python_package/qg_test.py:65, in ModelTest._check_existing_test_id(self)
#      63 for file in existing_files:
#      64     if file.startswith(f"{self.test_id}_") and file.endswith(".json"):
# ---> 65         raise ValueError(f"A test with ID {self.test_id} already exists. Please use a unique test ID.")
#
# ValueError: A test with ID 08 already exists. Please use a unique test ID.

# %% [markdown]
# # **Sum pooled jets**

# %%
with h5py.File("/home/reyguadarrama/GSoC/data/gluon_data/gluon_ECAL_sumpool_16x16.h5", 'r') as file:
    ECAL_gluon_16x16 = file['gluon_ECAL_sumpool_16x16'][:test.num_samples]

with h5py.File("/home/reyguadarrama/GSoC/data/gluon_data/gluon_HCAL_sumpool_16x16.h5", 'r') as file:
    HCAL_gluon_16x16 = file['gluon_HCAL_sumpool_16x16'][:test.num_samples]

# %%
gluon_ECAL_overlay = np.mean(ECAL_gluon_16x16, axis=0)
ECAL_total_energy = np.sum(ECAL_gluon_16x16, axis=(1,2))
ECAL_rechit_energy = ECAL_gluon_16x16[ECAL_gluon_16x16 > 0]

gluon_HCAL_overlay = np.mean(HCAL_gluon_16x16, axis=0)
HCAL_total_energy = np.sum(HCAL_gluon_16x16, axis=(1,2))
HCAL_rechit_energy = HCAL_gluon_16x16[HCAL_gluon_16x16 > 0]

# %%
fig, axs = plt.subplots(2, 2, figsize=(11, 11))

im1 = axs[0, 0].imshow(ECAL_gluon_16x16[0], cmap="Blues", norm=mcolors.LogNorm())
axs[0, 0].set_title("ECAL jet")

axs[0, 1].imshow(gluon_ECAL_overlay, cmap="Blues", norm=mcolors.LogNorm())
axs[0, 1].set_title("ECAL overlay")

im2 = axs[1, 0].imshow(HCAL_gluon_16x16[0], cmap="Purples", norm=mcolors.LogNorm())
axs[1, 0].set_title("HCAL jet")

axs[1, 1].imshow(gluon_HCAL_overlay, cmap="Purples", norm=mcolors.LogNorm())
axs[1, 1].set_title("HCAL overlay")

for ax in axs.flat:
    ax.set(xlabel="scaled i$\phi '$", ylabel="scaled i$\eta '$")

cbar1 = fig.colorbar(im1, ax=axs[0, :], orientation='vertical', fraction=0.02, pad=0.04)
cbar2 = fig.colorbar(im2, ax=axs[1, :], orientation='vertical', fraction=0.02, pad=0.04)

plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 11))

axs[0, 0].hist(ECAL_total_energy, bins=30, color="royalblue")
axs[0, 0].set_title("ECAL Scaled Total Energy Deposits", fontsize=15)
axs[0, 0].set_xlabel("Scaled energy")
axs[0, 0].set_ylabel("count")

axs[0, 1].hist(ECAL_rechit_energy, bins=30, color="royalblue")
axs[0, 1].set_title("ECAL Scaled Rechit Energy Deposits", fontsize=15)
axs[0, 1].set_xlabel("Scaled energy")
axs[0, 1].set_yscale("log")
axs[0, 1].set_ylabel("count")

axs[1, 0].hist(HCAL_total_energy, bins=30, color="mediumslateblue")
axs[1, 0].set_title("HCAL Scaled Total Energy Deposits", fontsize=15)
axs[1, 0].set_xlabel("Scaled energy")
axs[1, 0].set_ylabel("count")

axs[1, 1].hist(HCAL_rechit_energy, bins=30, color="mediumslateblue")
axs[1, 1].set_title("HCAL Scaled Rechit Energy Deposits", fontsize=15)
axs[1, 1].set_xlabel("Scaled energy")
axs[1, 1].set_yscale("log")
axs[1, 1].set_ylabel("count")

plt.show()

# %%
all_gluon_16x16 = np.stack((ECAL_gluon_16x16, HCAL_gluon_16x16), axis=-1)

# %%
t = np.mean(all_gluon_16x16, axis=0)
t.shape
# Out:
# (16, 16, 2)

# %%
plt.imshow(t[:,:,0], norm=mcolors.LogNorm())

# %%
plt.imshow(t[:,:,1], norm=mcolors.LogNorm())

# %% [markdown]
# # **Training**

# %%
class QuarkDataset(Dataset):
    def __init__(self, image):
        self.data = torch.tensor(image, dtype=torch.float32) 

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# %%
# Create the data loader instance
dataset = QuarkDataset(all_gluon_16x16.reshape(test.num_samples, 512))
dataloader = DataLoader(dataset, batch_size=test.batch_size, shuffle=True)

# %%
class Discriminator(nn.Module):
    """Fully connected classical discriminator"""

    def __init__(self):
        super().__init__()

        self.model = nn.Sequential(
            # Inputs to first hidden layer (num_input_features -> 64)
            nn.Linear(512, 256),
            nn.ReLU(),
            # First hidden layer (64 -> 16)
            nn.Linear(256, 128),
            nn.ReLU(),
            # Second hidden layer (16 -> output)
            nn.Linear(128, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.model(x)

# %%
dev = qml.device("default.qubit", wires=test.num_qubits)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

@qml.qnode(dev, diff_method="backprop")
def quantum_circuit(noise, weights, rotations):
    weights = weights.reshape(test.circuit_depth, test.num_qubits, len(rotations))

    # Initialise latent vectors
    for i in range(test.num_qubits):
        qml.RY(noise[i], wires=i)

    # Repeated layer
    for i in range(test.circuit_depth):
         # Parameterised layer
        for q in range(test.num_qubits):
            for idx, rotation in enumerate(rotations):
                if rotation == "X":
                    qml.RX(weights[i][q][idx], wires=q)
                elif rotation == "Y":
                    qml.RY(weights[i][q][idx], wires=q)
                elif rotation == "Z":
                    qml.RZ(weights[i][q][idx], wires=q)

        # Control Z gates
        for y in range(test.num_qubits - 1):
            qml.CZ(wires=[y, y + 1])
        qml.CZ(wires=[test.num_qubits - 1, 0])

    return qml.probs(wires=list(range(test.num_qubits)))

# %%
weights = torch.rand(test.num_qubits*test.circuit_depth*len(test.rotations))
noise = torch.rand(16, test.num_qubits, device=device) * np.pi / 2

# %%
qml.draw_mpl(quantum_circuit)(noise, weights, test.rotations)
plt.show()

# %%
def partial_measure(noise, weights, rotations):
    # Non-linear Transform
    probs = quantum_circuit(noise, weights, rotations)
    probsgiven0 = probs[: (2 ** (test.num_qubits - test.num_aux_qubits))]

    # Post-Processing
    probsgiven = (probsgiven0 / test.y) - test.shift
    probsgiven[probsgiven < test.cut_threshold] = 0
    return probsgiven

# %%
class PatchQuantumGenerator(nn.Module):
    """Quantum generator class for the patch method"""

    def __init__(self, n_generators, q_delta=1):
        """
        Args:
            n_generators (int): Number of sub-generators to be used in the patch method.
            q_delta (float, optional): Spread of the random distribution for parameter initialisation.
        """

        super().__init__()


        self.q_params = nn.ParameterList(
            [
                nn.Parameter(q_delta * torch.rand(test.num_qubits*test.circuit_depth*len(test.rotations)), requires_grad=True)
                for _ in range(n_generators)
            ]
        )

        self.n_generators = n_generators

    def forward(self, x, rotations):
        # Size of each sub-generator output
        patch_size = 2 ** (test.num_qubits - test.num_aux_qubits)

        # Create a Tensor to 'catch' a batch of images from the for loop. x.size(0) is the batch size.
        images = torch.Tensor(x.size(0), 0).to(device)

        # Iterate over all sub-generators
        for params in self.q_params:

            # Create a Tensor to 'catch' a batch of the patches from a single sub-generator
            patches = torch.Tensor(0, patch_size).to(device)
            for elem in x:
                q_out = partial_measure(elem, params, rotations).float().unsqueeze(0)
                patches = torch.cat((patches, q_out))

            # Each batch of patches is concatenated with each other to create a batch of images
            images = torch.cat((images, patches), 1)
            
        return images

# %%
def plot_training_progress():
    # we don't plot if we don't have enough data
    if len(rms_error) < 2:
        return

    clear_output(wait=True)
    fig, axs = plt.subplots(2, 2, figsize=(15, 12))

    # Metric 1
    axs[0, 0].set_title("RMSE", fontsize=15)
    axs[0, 0].plot(epochs, rms_error, color="slateblue", linewidth=3)
    axs[0, 0].set_xlabel("Epoch")
    axs[0, 0].set_yscale("log")
    axs[0, 0].grid()

    # Metric 2
    axs[0, 1].set_title("FID", fontsize=15)
    axs[0, 1].plot(epochs, fid, color="mediumslateblue", linewidth=3)
    axs[0, 1].set_xlabel("Epoch")
    axs[0, 1].set_yscale("log")
    axs[0, 1].grid()

    # Generated distribution
    axs[1, 0].imshow(gen_ECAL_overlay, cmap='Blues', aspect='auto', norm=mcolors.LogNorm())
    axs[1, 0].set_title('Generated ECAL overlay', fontsize=15)

    axs[1, 1].imshow(gen_HCAL_overlay, cmap='Purples', aspect='auto', norm=mcolors.LogNorm())
    axs[1, 1].set_title('Generated HCAL overlay', fontsize=15)

    plt.suptitle(f"Epoch {counter}", fontsize=25)
    plt.show()

# %%
discriminator = Discriminator().to(device)
generator = PatchQuantumGenerator(test.num_generators).to(device)

# Binary cross entropy
criterion = nn.BCELoss()

# Optimizers
optD = optim.SGD(discriminator.parameters(), lr=test.discriminator_lr)
optG = optim.SGD(generator.parameters(), lr=test.generator_lr)

real_labels = torch.full((test.batch_size,), 1.0, dtype=torch.float, device=device)
fake_labels = torch.full((test.batch_size,), 0.0, dtype=torch.float, device=device)

# Iteration counter
counter = 0

# plot lists
rms_error = []
fid = []
epochs = []
disc_loss = []
gen_loss = []

# %%
while counter < test.num_epochs:

    if counter%5 == 0:
        noise = torch.rand(test.num_samples, test.num_qubits, device=device)* np.pi / 2
        generated_jets = generator(noise, test.rotations).detach().numpy().reshape(test.num_samples, 16, 16, 2)
        gen_overlays = np.mean(generated_jets, axis=0)
        gen_ECAL_overlay = gen_overlays[:,:,0]
        gen_HCAL_overlay = gen_overlays[:,:,1]
        fd = FID(gluon_HCAL_overlay, gen_HCAL_overlay) + FID(gluon_ECAL_overlay, gen_ECAL_overlay)
        rms = np.sqrt(np.mean((gluon_HCAL_overlay - gen_HCAL_overlay) ** 2)) + np.sqrt(np.mean((gluon_ECAL_overlay - gen_ECAL_overlay) ** 2))
        fid.append(fd)
        rms_error.append(rms)
        epochs.append(counter)

        plot_training_progress()
    
    for i, data in enumerate(dataloader):


        # Data for training the discriminator
        real_data = data.to(device)

        # Noise follwing a uniform distribution in range [0,pi/2)
        noise = torch.rand(test.batch_size, test.num_qubits, device=device) * np.pi / 2
        fake_data = generator(noise, test.rotations)

        # Training the discriminator
        discriminator.zero_grad()
        outD_real = discriminator(real_data).view(-1)
        outD_fake = discriminator(fake_data.detach()).view(-1)

        errD_real = criterion(outD_real, real_labels)
        errD_fake = criterion(outD_fake, fake_labels)
        # Propagate gradients
        errD_real.backward()
        errD_fake.backward()

        errD = errD_real + errD_fake
        optD.step()

        # Training the generator
        generator.zero_grad()
        outD_fake = discriminator(fake_data).view(-1)
        errG = criterion(outD_fake, real_labels)
        errG.backward()
        optG.step()
            
    counter += 1
    disc_loss.append(errD)
    gen_loss.append(errG)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 25
#      23 # Noise follwing a uniform distribution in range [0,pi/2)
#      24 noise = torch.rand(test.batch_size, test.num_qubits, device=device) * np.pi / 2
# ---> 25 fake_data = generator(noise, test.rotations)
#      27 # Training the discriminator
#      28 discriminator.zero_grad()
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[18], line 36, in PatchQuantumGenerator.forward(self, x, rotations)
#      34 patches = torch.Tensor(0, patch_size).to(device)
#      35 for elem in x:
# ---> 36     q_out = partial_measure(elem, params, rotations).float().unsqueeze(0)
#      37     patches = torch.cat((patches, q_out))
#      39 # Each batch of patches is concatenated with each other to create a batch of images
#
# Cell In[17], line 3, in partial_measure(noise, weights, rotations)
#       1 def partial_measure(noise, weights, rotations):
#       2     # Non-linear Transform
# ----> 3     probs = quantum_circuit(noise, weights, rotations)
#       4     probsgiven0 = probs[: (2 ** (test.num_qubits - test.num_aux_qubits))]
#       6     # Post-Processing
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/workflow/qnode.py:1098, in QNode.__call__(self, *args, **kwargs)
#    1095 self._update_gradient_fn(shots=override_shots, tape=self._tape)
#    1097 try:
# -> 1098     res = self._execution_component(args, kwargs, override_shots=override_shots)
#    1099 finally:
#    1100     if old_interface == "auto":
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/workflow/qnode.py:1052, in QNode._execution_component(self, args, kwargs, override_shots)
#    1049 full_transform_program.prune_dynamic_transform()
#    1051 # pylint: disable=unexpected-keyword-arg
# -> 1052 res = qml.execute(
#    1053     (self._tape,),
#    1054     device=self.device,
#    1055     gradient_fn=self.gradient_fn,
#    1056     interface=self.interface,
#    1057     transform_program=full_transform_program,
#    1058     config=config,
#    1059     gradient_kwargs=self.gradient_kwargs,
#    1060     override_shots=override_shots,
#    1061     **self.execute_kwargs,
#    1062 )
#    1063 res = res[0]
#    1065 # convert result to the interface in case the qfunc has no parameters
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/workflow/execution.py:616, in execute(tapes, device, gradient_fn, interface, transform_program, config, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform, device_vjp)
#     614 # Exiting early if we do not need to deal with an interface boundary
#     615 if no_interface_boundary_required:
# --> 616     results = inner_execute(tapes)
#     617     return post_processing(results)
#     619 _grad_on_execution = False
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/workflow/execution.py:297, in _make_inner_execute.<locals>.inner_execute(tapes, **_)
#     294 transformed_tapes, transform_post_processing = transform_program(tapes)
#     296 if transformed_tapes:
# --> 297     results = device_execution(transformed_tapes)
#     298 else:
#     299     results = ()
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/devices/modifiers/simulator_tracking.py:30, in _track_execute.<locals>.execute(self, circuits, execution_config)
#      28 @wraps(untracked_execute)
#      29 def execute(self, circuits, execution_config=DefaultExecutionConfig):
# ---> 30     results = untracked_execute(self, circuits, execution_config)
#      31     if isinstance(circuits, QuantumScript):
#      32         batch = (circuits,)
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/devices/modifiers/single_tape_support.py:32, in _make_execute.<locals>.execute(self, circuits, execution_config)
#      30     is_single_circuit = True
#      31     circuits = (circuits,)
# ---> 32 results = batch_execute(self, circuits, execution_config)
#      33 return results[0] if is_single_circuit else results
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/devices/default_qubit.py:593, in DefaultQubit.execute(self, circuits, execution_config)
#     590 prng_keys = [self.get_prng_keys()[0] for _ in range(len(circuits))]
#     592 if max_workers is None:
# --> 593     return tuple(
#     594         _simulate_wrapper(
#     595             c,
#     596             {
#     597                 "rng": self._rng,
#     598                 "debugger": self._debugger,
#     599                 "interface": interface,
#     600                 "state_cache": self._state_cache,
#     601                 "prng_key": _key,
#     602             },
#     603         )
#     604         for c, _key in zip(circuits, prng_keys)
#     605     )
#     607 vanilla_circuits = [convert_to_numpy_parameters(c) for c in circuits]
#     608 seeds = self._rng.integers(2**31 - 1, size=len(vanilla_circuits))
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/devices/default_qubit.py:594, in <genexpr>(.0)
#     590 prng_keys = [self.get_prng_keys()[0] for _ in range(len(circuits))]
#     592 if max_workers is None:
#     593     return tuple(
# --> 594         _simulate_wrapper(
#     595             c,
#     596             {
#     597                 "rng": self._rng,
#     598                 "debugger": self._debugger,
#     599                 "interface": interface,
#     600                 "state_cache": self._state_cache,
#     601                 "prng_key": _key,
#     602             },
#     603         )
#     604         for c, _key in zip(circuits, prng_keys)
#     605     )
#     607 vanilla_circuits = [convert_to_numpy_parameters(c) for c in circuits]
#     608 seeds = self._rng.integers(2**31 - 1, size=len(vanilla_circuits))
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/devices/default_qubit.py:841, in _simulate_wrapper(circuit, kwargs)
#     840 def _simulate_wrapper(circuit, kwargs):
# --> 841     return simulate(circuit, **kwargs)
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/devices/qubit/simulate.py:287, in simulate(circuit, debugger, state_cache, **execution_kwargs)
#     282     return simulate_one_shot_native_mcm(
#     283         circuit, debugger=debugger, rng=rng, prng_key=prng_key, interface=interface
#     284     )
#     286 ops_key, meas_key = jax_random_split(prng_key)
# --> 287 state, is_state_batched = get_final_state(
#     288     circuit, debugger=debugger, rng=rng, prng_key=ops_key, interface=interface
#     289 )
#     290 if state_cache is not None:
#     291     state_cache[circuit.hash] = state
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/devices/qubit/simulate.py:167, in get_final_state(circuit, debugger, **execution_kwargs)
#     162         state, circuit._shots = _postselection_postprocess(
#     163             state, is_state_batched, circuit.shots, rng=rng, prng_key=key
#     164         )
#     166     # new state is batched if i) the old state is batched, or ii) the new op adds a batch dim
# --> 167     is_state_batched = is_state_batched or (op.batch_size is not None)
#     169 for _ in range(len(circuit.wires) - len(circuit.op_wires)):
#     170     # if any measured wires are not operated on, we pad the state with zeros.
#     171     # We know they belong at the end because the circuit is in standard wire-order
#     172     state = qml.math.stack([state, qml.math.zeros_like(state)], axis=-1)
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/operation.py:1223, in Operator.batch_size(self)
#    1212 r"""Batch size of the operator if it is used with broadcasted parameters.
#    1213
#    1214 The ``batch_size`` is determined based on ``ndim_params`` and the provided parameters
#    (...)
#    1220     int or None: Size of the parameter broadcasting dimension if present, else ``None``.
#    1221 """
#    1222 if self._batch_size is _UNSET_BATCH_SIZE:
# -> 1223     self._check_batching()
#    1224 return self._batch_size
#
# File ~/GSoC/GSoC_env/lib/python3.10/site-packages/pennylane/operation.py:1154, in Operator._check_batching(self)
#    1151     return
#    1153 self._ndim_params = ndims
# -> 1154 if ndims != self.ndim_params:
#    1155     ndims_matches = [
#    1156         (ndim == exp_ndim, ndim == exp_ndim + 1)
#    1157         for ndim, exp_ndim in zip(ndims, self.ndim_params)
#    1158     ]
#    1159     if not all(correct or batched for correct, batched in ndims_matches):
#
# KeyboardInterrupt:

# %% [markdown]
# # **Results**

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(25, 6))

# Metric 1
ax1.set_title("RMSE", fontsize=15)
ax1.plot(epochs, rms_error, color="slateblue", linewidth=3)
ax1.set_xlabel("Epoch")
ax1.grid()

# Metric 2
ax2.set_title("FID", fontsize=15)
ax2.plot(epochs, fid, color="mediumslateblue", linewidth=3)
ax2.set_xlabel("Epoch")
ax2.grid()

# Generated distribution
im = ax3.imshow(gen_HCAL_overlay, cmap='Purples', aspect='auto', norm=mcolors.LogNorm())
ax3.set_title('Generated HCAL overlay', fontsize=15)

fig.colorbar(im, ax=ax3)

plt.suptitle(f"Epoch {counter}", fontsize=25)
plt.show()

# %%
generated_jets = generator(torch.rand(test.num_samples, test.num_qubits, device=device) * np.pi / 2, test.rotations).detach().numpy().reshape(test.num_samples, 8, 8, 2)

# %%
ECAL_generated_jets = generated_jets[:,:,:,0]
HCAL_generated_jets = generated_jets[:,:,:,1]

# %%
fig, axs = plt.subplots(2, 3, figsize=(13, 9)) 

for j in range(3):
    jet = np.random.randint(0, 300)
    im1 = axs[0, j].imshow(ECAL_generated_jets[jet], cmap="Blues", norm=mcolors.LogNorm())
    axs[0, j].set_xlabel("Energy Deposits")
    axs[0, j].set_ylabel("jet count")

for j in range(3):
    jet = np.random.randint(0, 300)
    im1 = axs[1, j].imshow(all_gluon_16x16[jet,:,:,0], cmap="Blues", norm=mcolors.LogNorm())
    axs[1, j].set_xlabel("Energy Deposits")
    axs[1, j].set_ylabel("jet count")

for ax in axs.flat:
    ax.set(xlabel="scaled i$\phi '$", ylabel="scaled i$\eta '$")

cbar = fig.colorbar(im1, ax=axs, orientation='vertical', fraction=0.02, pad=0.04)

fig.text(0.5, 0.87, "Generated Jets (ECAL)", ha='center', fontsize=18)
fig.text(0.5, 0.45, "Real Jets (ECAL)", ha='center', fontsize=18)

plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(13, 9)) 

for j in range(3):
    jet = np.random.randint(0, 300)
    im1 = axs[0, j].imshow(HCAL_generated_jets[jet], cmap="Purples", norm=mcolors.LogNorm())
    axs[0, j].set_xlabel("Energy Deposits")
    axs[0, j].set_ylabel("jet count")

for j in range(3):
    jet = np.random.randint(0, 300)
    im1 = axs[1, j].imshow(all_gluon_16x16[jet,:,:,1], cmap="Purples", norm=mcolors.LogNorm())
    axs[1, j].set_xlabel("Energy Deposits")
    axs[1, j].set_ylabel("jet count")

for ax in axs.flat:
    ax.set(xlabel="scaled i$\phi '$", ylabel="scaled i$\eta '$")

cbar = fig.colorbar(im1, ax=axs, orientation='vertical', fraction=0.02, pad=0.04)

fig.text(0.5, 0.87, "Generated Jets (HCAL)", ha='center', fontsize=18)
fig.text(0.5, 0.45, "Real Jets (HCAL)", ha='center', fontsize=18)

plt.show()

# %%
gen_jets_image = np.mean(generated_jets[:,:,:,0], axis=0)
real_jets_image = np.mean(all_gluon_16x16[:,:,:,0], axis=0)

fig, axs =  plt.subplots(1, 2, figsize=(15, 7)) 

im1 = axs[0].imshow(real_jets_image, cmap="Blues", norm=mcolors.LogNorm())
axs[0].set_title("real ECAL overlay", fontsize=15)

im2 = axs[1].imshow(gen_jets_image, cmap='Blues', norm=mcolors.LogNorm())
axs[1].set_title("generated ECAL overlay", fontsize=15)

for ax in axs.flat:
    ax.set(xlabel="scaled i$\phi '$", ylabel="scaled i$\eta '$")

cbar = fig.colorbar(im1, ax=axs, orientation='vertical', fraction=0.02, pad=0.04)

# %%
gen_jets_image = np.mean(generated_jets[:,:,:,1], axis=0)
real_jets_image = np.mean(all_gluon_16x16[:,:,:,1], axis=0)

fig, axs =  plt.subplots(1, 2, figsize=(15, 7)) 

im1 = axs[0].imshow(real_jets_image, cmap="Purples", norm=mcolors.LogNorm())
axs[0].set_title("real HCAL overlay", fontsize=15)

im2 = axs[1].imshow(gen_jets_image, cmap='Purples', norm=mcolors.LogNorm())
axs[1].set_title("generated HCAL overlay", fontsize=15)

for ax in axs.flat:
    ax.set(xlabel="scaled i$\phi '$", ylabel="scaled i$\eta '$")

cbar = fig.colorbar(im1, ax=axs, orientation='vertical', fraction=0.02, pad=0.04)

# %%
ECAL_gen_total_energy = np.sum(generated_jets[:,:,:,0], axis=(1,2))
HCAL_gen_total_energy = np.sum(generated_jets[:,:,:,1], axis=(1,2))

# %%
plt.hist(ECAL_gen_total_energy, range=(0, 2.5), bins=30, color="royalblue", label="generated", histtype="step", linewidth=2)
plt.hist(ECAL_gen_total_energy, range=(0, 2.5), bins=30, color="royalblue", alpha=0.5)
plt.hist(ECAL_total_energy, range=(0, 2.5), bins=30, color="plum", label="real", histtype="step", linewidth=2)
plt.hist(ECAL_total_energy, range=(0, 2.5), bins=30, color="plum", alpha=0.5)
plt.title("Scaled total ECAL Energy deposits", fontsize=15)
plt.xlabel("scaled total energy", fontsize=13)
plt.ylabel("count", fontsize=13)
plt.legend()
plt.show()

# %%
plt.hist(HCAL_gen_total_energy, range=(0, 2.5), bins=30, color="mediumslateblue", label="generated", histtype="step", linewidth=2)
plt.hist(HCAL_gen_total_energy, range=(0, 2.5), bins=30, color="mediumslateblue", alpha=0.5)
plt.hist(HCAL_total_energy, range=(0, 2.5), bins=30, color="plum", label="real", histtype="step", linewidth=2)
plt.hist(HCAL_total_energy, range=(0, 2.5), bins=30, color="plum", alpha=0.5)
plt.title("Scaled total HCAL Energy deposits", fontsize=15)
plt.xlabel("scaled total energy", fontsize=13)
plt.ylabel("count", fontsize=13)
plt.legend()
plt.show()

# %%
ECAL_gen_rechit_energy = ECAL_generated_jets[ECAL_generated_jets > 0]
HCAL_gen_rechit_energy = HCAL_generated_jets[HCAL_generated_jets > 0]

# %%
plt.hist(ECAL_gen_rechit_energy, range=(0, 2), bins=40, color="royalblue", label="generated", histtype="step", linewidth=2)
plt.hist(ECAL_gen_rechit_energy, range=(0, 2), bins=40, color="royalblue", alpha=0.5)
plt.hist(ECAL_rechit_energy, range=(0, 2), bins=40, color="plum", label="real", histtype="step", linewidth=2)
plt.hist(ECAL_rechit_energy, range=(0, 2), bins=40, color="plum", alpha=0.5)
plt.title("Scaled rechit HCAL Energy deposits", fontsize=15)
plt.xlabel("scaled energy", fontsize=13)
plt.ylabel("count", fontsize=13)
plt.yscale("log")
plt.legend()
plt.show()

# %%
plt.hist(HCAL_gen_rechit_energy, range=(0, 2), bins=40, color="mediumslateblue", label="generated", histtype="step", linewidth=2)
plt.hist(HCAL_gen_rechit_energy, range=(0, 2), bins=40, color="mediumslateblue", alpha=0.5)
plt.hist(HCAL_rechit_energy, range=(0, 2), bins=40, color="plum", label="real", histtype="step", linewidth=2)
plt.hist(HCAL_rechit_energy, range=(0, 2), bins=40, color="plum", alpha=0.5)
plt.title("Scaled rechit HCAL Energy deposits", fontsize=15)
plt.xlabel("scaled energy", fontsize=13)
plt.ylabel("count", fontsize=13)
plt.yscale("log")
plt.legend()
plt.show()

# %%
total_energy = ECAL_total_energy + HCAL_total_energy
gen_total_energy = ECAL_gen_total_energy + HCAL_gen_total_energy

# %%
plt.hist(gen_total_energy, range=(0, 2.5), bins=30, color="darkcyan", label="generated", histtype="step", linewidth=2)
plt.hist(gen_total_energy, range=(0, 2.5), bins=30, color="darkcyan", alpha=0.5)
plt.hist(total_energy, range=(0, 2.5), bins=30, color="plum", label="real", histtype="step", linewidth=2)
plt.hist(total_energy, range=(0, 2.5), bins=30, color="plum", alpha=0.5)
plt.title("Scaled total Energy deposits", fontsize=15)
plt.xlabel("scaled total energy", fontsize=13)
plt.ylabel("count", fontsize=13)
plt.legend()
plt.show()

# %% [markdown]
# # **Save Results**

# %%
metrics = {
    'FID': "{:.2e}".format(fid[-1]),
    'RMSE': "{:.2e}".format(rms_error[-1]),
    'discriminator loss': "{:.2e}".format(disc_loss[-1]),
    'generator loss': "{:.2e}".format(gen_loss[-1]),
    'notes': "analysis pending"
}

test.save_results_to_json(metrics=metrics)
test.save_trained_params(generator=generator)

# %%
# %run summary.py
# Out:
# The README.md has been updated with the results table.
