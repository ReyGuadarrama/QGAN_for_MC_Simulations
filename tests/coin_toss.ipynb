# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import pennylane as qml
import random
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader

# %%
# Set the random seed for reproducibility
seed = 23
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# %%
np.random.randint(0, 2)
# Out:
# 1

# %%
# Generate 20000 samples of the sum of rolling two six-sided dice

def coin_toss(n_samples: int, coins: int) -> np.array:
    coin_tosses = np.random.randint(2, size=(n_samples, coins))
    return np.sum(coin_tosses, axis=1)



coin_tosses = coin_toss(n_samples=20000, coins=10)

# %%
def calculate_probabilities(samples, batch_size):
        # Initialize an array to hold counts of each possible result (0 to 15)
        probs = []
        
        for i in range(int(len(samples)/batch_size)):
            counts = np.zeros(16)
            data = samples[i*batch_size:(i+1)*batch_size]
            # Count the occurrences of each result
            for value in data:
                counts[int(value)] += 1
            
            # Calculate probabilities by normalizing the counts
            probabilities = counts / len(data)
            probs.append(probabilities)
        
        return np.array(probs)

probs = calculate_probabilities(coin_tosses, 2000)

# %%
class DistributionDataset(Dataset):
    def __init__(self, probs):
        self.data = torch.tensor(probs, dtype=torch.float32) 

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# %%
# Create the data loader instance
dataset = DistributionDataset(probs)
dataloader = DataLoader(dataset, batch_size=1)

# %%
# Discriminator implementation

class Discriminator(nn.Module):
    """Fully connected classical discriminator"""

    def __init__(self):
        super().__init__()

        self.model = nn.Sequential(
            # Inputs to first hidden layer (num_input_features -> 64)
            nn.Linear(16, 50),
            nn.LeakyReLU(),
            # First hidden layer (64 -> 16)
            nn.Linear(50, 20),
            nn.LeakyReLU(),
            # Second hidden layer (16 -> output)
            nn.Linear(20, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        x = x.reshape(x.size(0), -1)
        
        return self.model(x)

# %%
n_qubits = 4
n_a_qubits = 0
q_depth = 3

# %%
dev = qml.device("lightning.qubit", wires=n_qubits, shots=2000)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

@qml.qnode(dev, diff_method="parameter-shift")
def quantum_circuit(weights):

    weights = weights.reshape(q_depth, n_qubits)

    # Initialise latent vectors
    for i in range(n_qubits):
        qml.Hadamard(wires=i)
    qml.Barrier(wires=list(range(n_qubits)), only_visual=True)

    # Repeated layer
    for i in range(q_depth):
        # Parameterised layer
        for y in range(n_qubits):
            qml.RY(weights[i][y], wires=y)

        # Control Z gates
        for y in range(n_qubits - 1):
            qml.CZ(wires=[y, y + 1])

        #qml.CZ(wires=[5, 0])

        qml.Barrier(wires=list(range(n_qubits)), only_visual=True)

    return qml.probs(wires=list(range(n_qubits)))

noise = torch.rand(1, n_qubits, device=device) 
weights = torch.rand(1, n_qubits*q_depth) 

qml.draw_mpl(quantum_circuit)(weights=weights)
plt.show()

# %%
class QuantumGenerator(nn.Module):
    """Quantum generator class for the patch method"""

    def __init__(self):
        """
        Args:
            n_generators (int): Number of sub-generators to be used in the patch method.
            q_delta (float, optional): Spread of the random distribution for parameter initialisation.
        """

        super().__init__()

        self.q_params = nn.ParameterList(
            [
                nn.Parameter(torch.rand(q_depth * n_qubits), requires_grad=True)
            ]
        )

    def forward(self):

        qc_out = quantum_circuit(self.q_params[0]).float().unsqueeze(0)
        
        return qc_out

# %%
discriminator = Discriminator().to(device)
generator = QuantumGenerator().to(device)

# %%
for param in generator.parameters():
    print(param)
# Out:
# Parameter containing:
# tensor([0.5054, 0.3207, 0.4644, 0.5720, 0.7947, 0.2860, 0.2769, 0.6295, 0.5665,
#         0.1527, 0.9734, 0.6077], requires_grad=True)

# %%
lrG = 0.3  # Learning rate for the generator
lrD = 0.01  # Learning rate for the discriminator
num_iter = 500  # Number of training iterations

# %%
# Binary cross entropy
criterion = nn.BCELoss()

# Optimisers
optD = optim.SGD(discriminator.parameters(), lr=lrD)
optG = optim.SGD(generator.parameters(), lr=lrG)

real_labels = torch.full((1,), 1.0, dtype=torch.float, device=device)
fake_labels = torch.full((1,), 0.0, dtype=torch.float, device=device)

# Fixed noise allows us to visually track the generated images throughout training
fixed_noise = torch.rand(1, n_qubits, device=device) * np.pi / 2

# Iteration counter
counter = 0

# Collect images for plotting later
disc_loss = []
gen_loss = []

# %%
t = generator()
discriminator(t)
# Out:
# tensor([[0.5393]], grad_fn=<SigmoidBackward0>)

# %%
while True:
    for i, data in enumerate(dataloader):

        # Data for training the discriminator
        #data = data.reshape(-1, data.size(0))
        real_data = data.to(device)

        # Noise follwing a uniform distribution in range [0,pi/2)
        #noise = torch.rand(1, n_qubits, device=device) * np.pi / 2
        fake_data = generator()

        # Training the discriminator
        discriminator.zero_grad()
        outD_real = discriminator(real_data).view(-1)
        outD_fake = discriminator(fake_data.detach()).view(-1)

        errD_real = criterion(outD_real, real_labels)
        errD_fake = criterion(outD_fake, fake_labels)
        # Propagate gradients
        errD_real.backward()
        errD_fake.backward()

        errD = errD_real + errD_fake
        

        optD.step()
        

        # Training the generator
        generator.zero_grad()
        outD_fake = discriminator(fake_data).view(-1)
        errG = criterion(outD_fake, real_labels)
        

        errG.backward()
        optG.step()

        

    # Show loss values
    if counter % 10 == 0:
        print(f'Iteration: {counter}, Discriminator Loss: {errD:0.3f}, Generator Loss: {errG:0.3f}')
        gen_loss.append(errG.detach())
        disc_loss.append(errD.detach())

    counter += 1
    if counter == num_iter:
        break
# Out:
# Iteration: 0, Discriminator Loss: 1.397, Generator Loss: 0.622
# Iteration: 10, Discriminator Loss: 1.384, Generator Loss: 0.658
# Iteration: 20, Discriminator Loss: 1.378, Generator Loss: 0.681
# Iteration: 30, Discriminator Loss: 1.377, Generator Loss: 0.692
# Iteration: 40, Discriminator Loss: 1.371, Generator Loss: 0.704
# Iteration: 50, Discriminator Loss: 1.376, Generator Loss: 0.703
# Iteration: 60, Discriminator Loss: 1.386, Generator Loss: 0.692
# Iteration: 70, Discriminator Loss: 1.389, Generator Loss: 0.689
# Iteration: 80, Discriminator Loss: 1.388, Generator Loss: 0.690
# Iteration: 90, Discriminator Loss: 1.385, Generator Loss: 0.694
# Iteration: 100, Discriminator Loss: 1.382, Generator Loss: 0.697
# Iteration: 110, Discriminator Loss: 1.380, Generator Loss: 0.699
# Iteration: 120, Discriminator Loss: 1.379, Generator Loss: 0.699
# Iteration: 130, Discriminator Loss: 1.376, Generator Loss: 0.700
# Iteration: 140, Discriminator Loss: 1.374, Generator Loss: 0.702
# Iteration: 150, Discriminator Loss: 1.373, Generator Loss: 0.702
# Iteration: 160, Discriminator Loss: 1.372, Generator Loss: 0.701
# Iteration: 170, Discriminator Loss: 1.368, Generator Loss: 0.704
# Iteration: 180, Discriminator Loss: 1.368, Generator Loss: 0.703
# Iteration: 190, Discriminator Loss: 1.376, Generator Loss: 0.696
# Iteration: 200, Discriminator Loss: 1.380, Generator Loss: 0.695
# Iteration: 210, Discriminator Loss: 1.377, Generator Loss: 0.699
# Iteration: 220, Discriminator Loss: 1.375, Generator Loss: 0.701
# Iteration: 230, Discriminator Loss: 1.379, Generator Loss: 0.696
# Iteration: 240, Discriminator Loss: 1.380, Generator Loss: 0.697
# Iteration: 250, Discriminator Loss: 1.366, Generator Loss: 0.709
# Iteration: 260, Discriminator Loss: 1.361, Generator Loss: 0.711
# Iteration: 270, Discriminator Loss: 1.358, Generator Loss: 0.713
# Iteration: 280, Discriminator Loss: 1.385, Generator Loss: 0.686
# Iteration: 290, Discriminator Loss: 1.383, Generator Loss: 0.691
# Iteration: 300, Discriminator Loss: 1.382, Generator Loss: 0.693
# Iteration: 310, Discriminator Loss: 1.383, Generator Loss: 0.694
# Iteration: 320, Discriminator Loss: 1.383, Generator Loss: 0.695
# Iteration: 330, Discriminator Loss: 1.383, Generator Loss: 0.695
# Iteration: 340, Discriminator Loss: 1.384, Generator Loss: 0.694
# Iteration: 350, Discriminator Loss: 1.383, Generator Loss: 0.695
# Iteration: 360, Discriminator Loss: 1.383, Generator Loss: 0.694
# Iteration: 370, Discriminator Loss: 1.383, Generator Loss: 0.695
# Iteration: 380, Discriminator Loss: 1.384, Generator Loss: 0.694
# Iteration: 390, Discriminator Loss: 1.384, Generator Loss: 0.694
# Iteration: 400, Discriminator Loss: 1.382, Generator Loss: 0.695
# Iteration: 410, Discriminator Loss: 1.382, Generator Loss: 0.696
# Iteration: 420, Discriminator Loss: 1.382, Generator Loss: 0.694
# Iteration: 430, Discriminator Loss: 1.382, Generator Loss: 0.695
# Iteration: 440, Discriminator Loss: 1.383, Generator Loss: 0.694
# Iteration: 450, Discriminator Loss: 1.382, Generator Loss: 0.695
# Iteration: 460, Discriminator Loss: 1.382, Generator Loss: 0.695
# Iteration: 470, Discriminator Loss: 1.381, Generator Loss: 0.695
# Iteration: 480, Discriminator Loss: 1.380, Generator Loss: 0.696
# Iteration: 490, Discriminator Loss: 1.380, Generator Loss: 0.696

# %%
plt.plot(gen_loss, label="generator loss", color='royalblue', linewidth=2.5)
plt.plot(disc_loss, label="discriminator loss", color="plum", linewidth=2.5)
plt.legend()
plt.show()

# %%
t = generator().detach().numpy()
x = list(range(16))
plt.bar(x, t[0], color="cornflowerblue", label="generated distribution")
plt.bar(x, probs[8], color="plum", alpha=0.7, label="real distribution")
plt.legend()
plt.show()
